# %%
import pandas as pd
from sklearn.preprocessing import KBinsDiscretizer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, ConfusionMatrixDisplay
from sklearn.preprocessing import MinMaxScaler, StandardScaler

X_train = pd.read_csv('../data/X_train.csv')
X_test = pd.read_csv('../data/X_test.csv')
Y_train = pd.read_csv('../data/Y_train.csv')
Y_test = pd.read_csv('../data/Y_test.csv')

enc = KBinsDiscretizer(n_bins=10, encode="ordinal", strategy="kmeans")
Y_train_binned = enc.fit_transform(Y_train)
Y_test_binned = enc.fit_transform(Y_test)

X_train.shape, X_test.shape, Y_train.shape, Y_test.shape, Y_train_binned.shape, Y_test_binned.shape
# Out:
# ((2344, 136), (586, 136), (2344, 1), (586, 1), (2344, 1), (586, 1))

# %% [markdown]
# # k-Nearest-Neighbor Classifiers

# %%
kNN = KNeighborsClassifier(n_neighbors=2)
kNN.fit(X_train, Y_train_binned.ravel())

y_pred_train = kNN.predict(X_train)
print("Accuracy: {:.3f}".format(accuracy_score(y_true=Y_train_binned,
                                               y_pred=y_pred_train)))

y_pred_test = kNN.predict(X_test)
print("Accuracy: {:.3f}".format(accuracy_score(y_true=Y_test_binned,
                                               y_pred=y_pred_test)))
# Out:
# Accuracy: 0.774
# Accuracy: 0.502

# %% [markdown]
# # Scaling

# %%
for f in X_train.columns:
    print("Feature {:s} -> Scale: {:7.2f}".format(f, X_train.loc[:, f].max() - X_train.loc[:, f].min()))
# Out:
# Feature Lot_Frontage -> Scale:  313.00
# Feature Lot_Area -> Scale: 213775.00
# Feature Utilities -> Scale:    1.00
# Feature Land_Slope -> Scale:    2.00
# Feature Overall_Qual -> Scale:    9.00
# Feature Overall_Cond -> Scale:    8.00
# Feature Year_Built -> Scale:  138.00
# Feature Year_Remod_Add -> Scale:   60.00
# Feature Mas_Vnr_Area -> Scale: 1600.00
# Feature Exter_Qual -> Scale:    3.00
# Feature Exter_Cond -> Scale:    3.00
# Feature BsmtFin_SF_1 -> Scale:    7.00
# Feature BsmtFin_SF_2 -> Scale: 1474.00
# Feature Bsmt_Unf_SF -> Scale: 2336.00
# Feature Total_Bsmt_SF -> Scale: 5095.00
# Feature First_Flr_SF -> Scale: 4761.00
# Feature Second_Flr_SF -> Scale: 1872.00
# Feature Low_Qual_Fin_SF -> Scale: 1064.00
# Feature Gr_Liv_Area -> Scale: 4761.00
# Feature Bsmt_Full_Bath -> Scale:    3.00
# Feature Bsmt_Half_Bath -> Scale:    2.00
# Feature Full_Bath -> Scale:    4.00
# Feature Half_Bath -> Scale:    2.00
# Feature Bedroom_AbvGr -> Scale:    8.00
# Feature Kitchen_AbvGr -> Scale:    3.00
# Feature Kitchen_Qual -> Scale:    4.00
# Feature TotRms_AbvGrd -> Scale:   13.00
# Feature Fireplaces -> Scale:    4.00
# Feature Garage_Cars -> Scale:    4.00
# Feature Garage_Area -> Scale: 1488.00
# Feature Wood_Deck_SF -> Scale:  857.00
# Feature Open_Porch_SF -> Scale:  742.00
# Feature Enclosed_Porch -> Scale: 1012.00
# Feature Three_season_porch -> Scale:  407.00
# Feature Screen_Porch -> Scale:  576.00
# Feature Pool_Area -> Scale:  800.00
# Feature Misc_Val -> Scale: 17000.00
# Feature Mo_Sold -> Scale:   11.00
# Feature Year_Sold -> Scale:    4.00
# Feature Longitude -> Scale:    0.12
# Feature Latitude -> Scale:    0.08
# Feature MS_SubClass_b'One_Story_1946_and_Newer_All_Styles' -> Scale:    1.00
# Feature MS_SubClass_b'Two_Story_1946_and_Newer' -> Scale:    1.00
# Feature MS_SubClass_infrequent_sklearn -> Scale:    1.00
# Feature MS_Zoning_b'Residential_Low_Density' -> Scale:    1.00
# Feature MS_Zoning_b'Residential_Medium_Density' -> Scale:    1.00
# Feature MS_Zoning_infrequent_sklearn -> Scale:    1.00
# Feature Street_b'Pave' -> Scale:    1.00
# Feature Street_infrequent_sklearn -> Scale:    1.00
# Feature Alley_b'No_Alley_Access' -> Scale:    1.00
# Feature Alley_infrequent_sklearn -> Scale:    1.00
# Feature Lot_Shape_b'Regular' -> Scale:    1.00
# Feature Lot_Shape_b'Slightly_Irregular' -> Scale:    1.00
# Feature Lot_Shape_infrequent_sklearn -> Scale:    1.00
# Feature Land_Contour_b'Lvl' -> Scale:    1.00
# Feature Land_Contour_infrequent_sklearn -> Scale:    1.00
# Feature Lot_Config_b'Corner' -> Scale:    1.00
# Feature Lot_Config_b'Inside' -> Scale:    1.00
# Feature Lot_Config_infrequent_sklearn -> Scale:    1.00
# Feature Neighborhood_b'North_Ames' -> Scale:    1.00
# Feature Neighborhood_infrequent_sklearn -> Scale:    1.00
# Feature Condition_1_b'Norm' -> Scale:    1.00
# Feature Condition_1_infrequent_sklearn -> Scale:    1.00
# Feature Condition_2_b'Norm' -> Scale:    1.00
# Feature Condition_2_infrequent_sklearn -> Scale:    1.00
# Feature Bldg_Type_b'OneFam' -> Scale:    1.00
# Feature Bldg_Type_infrequent_sklearn -> Scale:    1.00
# Feature House_Style_b'One_Story' -> Scale:    1.00
# Feature House_Style_b'Two_Story' -> Scale:    1.00
# Feature House_Style_infrequent_sklearn -> Scale:    1.00
# Feature Roof_Style_b'Gable' -> Scale:    1.00
# Feature Roof_Style_b'Hip' -> Scale:    1.00
# Feature Roof_Style_infrequent_sklearn -> Scale:    1.00
# Feature Roof_Matl_b'CompShg' -> Scale:    1.00
# Feature Roof_Matl_infrequent_sklearn -> Scale:    1.00
# Feature Exterior_1st_b'HdBoard' -> Scale:    1.00
# Feature Exterior_1st_b'MetalSd' -> Scale:    1.00
# Feature Exterior_1st_b'VinylSd' -> Scale:    1.00
# Feature Exterior_1st_infrequent_sklearn -> Scale:    1.00
# Feature Exterior_2nd_b'VinylSd' -> Scale:    1.00
# Feature Exterior_2nd_infrequent_sklearn -> Scale:    1.00
# Feature Mas_Vnr_Type_b'BrkFace' -> Scale:    1.00
# Feature Mas_Vnr_Type_b'None' -> Scale:    1.00
# Feature Mas_Vnr_Type_infrequent_sklearn -> Scale:    1.00
# Feature Foundation_b'CBlock' -> Scale:    1.00
# Feature Foundation_b'PConc' -> Scale:    1.00
# Feature Foundation_infrequent_sklearn -> Scale:    1.00
# Feature Bsmt_Qual_b'Good' -> Scale:    1.00
# Feature Bsmt_Qual_b'Typical' -> Scale:    1.00
# Feature Bsmt_Qual_infrequent_sklearn -> Scale:    1.00
# Feature Bsmt_Cond_b'Typical' -> Scale:    1.00
# Feature Bsmt_Cond_infrequent_sklearn -> Scale:    1.00
# Feature Bsmt_Exposure_b'No' -> Scale:    1.00
# Feature Bsmt_Exposure_infrequent_sklearn -> Scale:    1.00
# Feature BsmtFin_Type_1_b'GLQ' -> Scale:    1.00
# Feature BsmtFin_Type_1_b'Unf' -> Scale:    1.00
# Feature BsmtFin_Type_1_infrequent_sklearn -> Scale:    1.00
# Feature BsmtFin_Type_2_b'Unf' -> Scale:    1.00
# Feature BsmtFin_Type_2_infrequent_sklearn -> Scale:    1.00
# Feature Heating_b'GasA' -> Scale:    1.00
# Feature Heating_infrequent_sklearn -> Scale:    1.00
# Feature Heating_QC_b'Excellent' -> Scale:    1.00
# Feature Heating_QC_b'Good' -> Scale:    1.00
# Feature Heating_QC_b'Typical' -> Scale:    1.00
# Feature Heating_QC_infrequent_sklearn -> Scale:    1.00
# Feature Central_Air_b'Y' -> Scale:    1.00
# Feature Central_Air_infrequent_sklearn -> Scale:    1.00
# Feature Electrical_b'SBrkr' -> Scale:    1.00
# Feature Electrical_infrequent_sklearn -> Scale:    1.00
# Feature Functional_b'Typ' -> Scale:    1.00
# Feature Functional_infrequent_sklearn -> Scale:    1.00
# Feature Fireplace_Qu_b'Good' -> Scale:    1.00
# Feature Fireplace_Qu_b'No_Fireplace' -> Scale:    1.00
# Feature Fireplace_Qu_b'Typical' -> Scale:    1.00
# Feature Fireplace_Qu_infrequent_sklearn -> Scale:    1.00
# Feature Garage_Type_b'Attchd' -> Scale:    1.00
# Feature Garage_Type_b'Detchd' -> Scale:    1.00
# Feature Garage_Type_infrequent_sklearn -> Scale:    1.00
# Feature Garage_Finish_b'Fin' -> Scale:    1.00
# Feature Garage_Finish_b'RFn' -> Scale:    1.00
# Feature Garage_Finish_b'Unf' -> Scale:    1.00
# Feature Garage_Finish_infrequent_sklearn -> Scale:    1.00
# Feature Garage_Qual_b'Typical' -> Scale:    1.00
# Feature Garage_Qual_infrequent_sklearn -> Scale:    1.00
# Feature Garage_Cond_b'Typical' -> Scale:    1.00
# Feature Garage_Cond_infrequent_sklearn -> Scale:    1.00
# Feature Paved_Drive_b'Paved' -> Scale:    1.00
# Feature Paved_Drive_infrequent_sklearn -> Scale:    1.00
# Feature Fence_b'No_Fence' -> Scale:    1.00
# Feature Fence_infrequent_sklearn -> Scale:    1.00
# Feature Misc_Feature_b'None' -> Scale:    1.00
# Feature Misc_Feature_infrequent_sklearn -> Scale:    1.00
# Feature Sale_Type_b'WD ' -> Scale:    1.00
# Feature Sale_Type_infrequent_sklearn -> Scale:    1.00
# Feature Sale_Condition_b'Normal' -> Scale:    1.00
# Feature Sale_Condition_infrequent_sklearn -> Scale:    1.00

# %% [markdown]
# ## Applico MinMaxScaler

# %%
scaler = MinMaxScaler()
scaler.fit(X_train)

best_accuracy = 0
best_k = 1
for k in range(1, 100):
    kNN = KNeighborsClassifier(n_neighbors=k)
    kNN.fit(scaler.transform(X_train), Y_train_binned.ravel())
    y_pred = kNN.predict(scaler.transform(X_test))

    # compute Accuracy
    acc = accuracy_score(y_true=Y_test_binned, y_pred=y_pred)
    best_accuracy = acc if acc > best_accuracy else best_accuracy
    best_k = k if best_accuracy == acc else best_k
    print("k: {:2d} | Accuracy {:.3f}".format(k, acc))

print("\nBest k: {:2d} | Accuracy {:.3f}".format(best_k, best_accuracy))
# Out:
# k:  1 | Accuracy 0.520
# k:  2 | Accuracy 0.491
# k:  3 | Accuracy 0.529
# k:  4 | Accuracy 0.532
# k:  5 | Accuracy 0.553
# k:  6 | Accuracy 0.548
# k:  7 | Accuracy 0.551
# k:  8 | Accuracy 0.546
# k:  9 | Accuracy 0.563
# k: 10 | Accuracy 0.555
# k: 11 | Accuracy 0.549
# k: 12 | Accuracy 0.529
# k: 13 | Accuracy 0.543
# k: 14 | Accuracy 0.534
# k: 15 | Accuracy 0.527
# k: 16 | Accuracy 0.536
# k: 17 | Accuracy 0.541
# k: 18 | Accuracy 0.539
# k: 19 | Accuracy 0.534
# k: 20 | Accuracy 0.532
# k: 21 | Accuracy 0.536
# k: 22 | Accuracy 0.526
# k: 23 | Accuracy 0.539
# k: 24 | Accuracy 0.532
# k: 25 | Accuracy 0.536
# k: 26 | Accuracy 0.527
# k: 27 | Accuracy 0.526
# k: 28 | Accuracy 0.531
# k: 29 | Accuracy 0.529
# k: 30 | Accuracy 0.520
# k: 31 | Accuracy 0.526
# k: 32 | Accuracy 0.531
# k: 33 | Accuracy 0.529
# k: 34 | Accuracy 0.526
# k: 35 | Accuracy 0.532
# k: 36 | Accuracy 0.532
# k: 37 | Accuracy 0.532
# k: 38 | Accuracy 0.529
# k: 39 | Accuracy 0.526
# k: 40 | Accuracy 0.531
# k: 41 | Accuracy 0.534
# k: 42 | Accuracy 0.538
# k: 43 | Accuracy 0.532
# k: 44 | Accuracy 0.531
# k: 45 | Accuracy 0.534
# k: 46 | Accuracy 0.526
# k: 47 | Accuracy 0.524
# k: 48 | Accuracy 0.520
# k: 49 | Accuracy 0.520
# k: 50 | Accuracy 0.520
# k: 51 | Accuracy 0.520
# k: 52 | Accuracy 0.522
# k: 53 | Accuracy 0.527
# k: 54 | Accuracy 0.524
# k: 55 | Accuracy 0.527
# k: 56 | Accuracy 0.519
# k: 57 | Accuracy 0.519
# k: 58 | Accuracy 0.517
# k: 59 | Accuracy 0.520
# k: 60 | Accuracy 0.522
# k: 61 | Accuracy 0.519
# k: 62 | Accuracy 0.524
# k: 63 | Accuracy 0.519
# k: 64 | Accuracy 0.519
# k: 65 | Accuracy 0.514
# k: 66 | Accuracy 0.507
# k: 67 | Accuracy 0.505
# k: 68 | Accuracy 0.498
# k: 69 | Accuracy 0.502
# k: 70 | Accuracy 0.495
# k: 71 | Accuracy 0.495
# k: 72 | Accuracy 0.488
# k: 73 | Accuracy 0.491
# k: 74 | Accuracy 0.488
# k: 75 | Accuracy 0.486
# k: 76 | Accuracy 0.485
# k: 77 | Accuracy 0.490
# k: 78 | Accuracy 0.493
# k: 79 | Accuracy 0.490
# k: 80 | Accuracy 0.488
# k: 81 | Accuracy 0.486
# k: 82 | Accuracy 0.490
# k: 83 | Accuracy 0.491
# k: 84 | Accuracy 0.493
# k: 85 | Accuracy 0.490
# k: 86 | Accuracy 0.493
# k: 87 | Accuracy 0.490
# k: 88 | Accuracy 0.490
# k: 89 | Accuracy 0.495
# k: 90 | Accuracy 0.493
# k: 91 | Accuracy 0.491
# k: 92 | Accuracy 0.491
# k: 93 | Accuracy 0.493
# k: 94 | Accuracy 0.491
# k: 95 | Accuracy 0.493
# k: 96 | Accuracy 0.490
# k: 97 | Accuracy 0.488
# k: 98 | Accuracy 0.486
# k: 99 | Accuracy 0.486
#
# Best k:  9 | Accuracy 0.563

# %%
scaler = StandardScaler()
scaler.fit(X_train)

best_accuracy = 0
best_k = 1
for k in range(1, 100):
    kNN = KNeighborsClassifier(n_neighbors=k)
    kNN.fit(scaler.transform(X_train), Y_train_binned.ravel())
    y_pred = kNN.predict(scaler.transform(X_test))

    # compute Accuracy
    acc = accuracy_score(y_true=Y_test_binned, y_pred=y_pred)
    best_accuracy = acc if acc > best_accuracy else best_accuracy
    best_k = k if best_accuracy == acc else best_k
    print("k: {:2d} | Accuracy {:.3f}".format(k, acc))

print("\nBest k: {:2d} | Accuracy {:.3f}".format(best_k, best_accuracy))
# Out:
# k:  1 | Accuracy 0.531
# k:  2 | Accuracy 0.503
# k:  3 | Accuracy 0.546
# k:  4 | Accuracy 0.549
# k:  5 | Accuracy 0.570
# k:  6 | Accuracy 0.555
# k:  7 | Accuracy 0.570
# k:  8 | Accuracy 0.561
# k:  9 | Accuracy 0.565
# k: 10 | Accuracy 0.563
# k: 11 | Accuracy 0.549
# k: 12 | Accuracy 0.548
# k: 13 | Accuracy 0.544
# k: 14 | Accuracy 0.544
# k: 15 | Accuracy 0.541
# k: 16 | Accuracy 0.560
# k: 17 | Accuracy 0.558
# k: 18 | Accuracy 0.553
# k: 19 | Accuracy 0.549
# k: 20 | Accuracy 0.549
# k: 21 | Accuracy 0.549
# k: 22 | Accuracy 0.539
# k: 23 | Accuracy 0.536
# k: 24 | Accuracy 0.555
# k: 25 | Accuracy 0.543
# k: 26 | Accuracy 0.543
# k: 27 | Accuracy 0.539
# k: 28 | Accuracy 0.543
# k: 29 | Accuracy 0.546
# k: 30 | Accuracy 0.546
# k: 31 | Accuracy 0.549
# k: 32 | Accuracy 0.553
# k: 33 | Accuracy 0.560
# k: 34 | Accuracy 0.546
# k: 35 | Accuracy 0.556
# k: 36 | Accuracy 0.544
# k: 37 | Accuracy 0.546
# k: 38 | Accuracy 0.549
# k: 39 | Accuracy 0.546
# k: 40 | Accuracy 0.546
# k: 41 | Accuracy 0.544
# k: 42 | Accuracy 0.546
# k: 43 | Accuracy 0.549
# k: 44 | Accuracy 0.544
# k: 45 | Accuracy 0.548
# k: 46 | Accuracy 0.543
# k: 47 | Accuracy 0.543
# k: 48 | Accuracy 0.539
# k: 49 | Accuracy 0.541
# k: 50 | Accuracy 0.541
# k: 51 | Accuracy 0.538
# k: 52 | Accuracy 0.531
# k: 53 | Accuracy 0.532
# k: 54 | Accuracy 0.531
# k: 55 | Accuracy 0.531
# k: 56 | Accuracy 0.524
# k: 57 | Accuracy 0.524
# k: 58 | Accuracy 0.526
# k: 59 | Accuracy 0.522
# k: 60 | Accuracy 0.524
# k: 61 | Accuracy 0.531
# k: 62 | Accuracy 0.519
# k: 63 | Accuracy 0.520
# k: 64 | Accuracy 0.514
# k: 65 | Accuracy 0.509
# k: 66 | Accuracy 0.510
# k: 67 | Accuracy 0.505
# k: 68 | Accuracy 0.512
# k: 69 | Accuracy 0.509
# k: 70 | Accuracy 0.514
# k: 71 | Accuracy 0.520
# k: 72 | Accuracy 0.519
# k: 73 | Accuracy 0.517
# k: 74 | Accuracy 0.512
# k: 75 | Accuracy 0.514
# k: 76 | Accuracy 0.517
# k: 77 | Accuracy 0.512
# k: 78 | Accuracy 0.509
# k: 79 | Accuracy 0.512
# k: 80 | Accuracy 0.510
# k: 81 | Accuracy 0.512
# k: 82 | Accuracy 0.515
# k: 83 | Accuracy 0.512
# k: 84 | Accuracy 0.514
# k: 85 | Accuracy 0.512
# k: 86 | Accuracy 0.510
# k: 87 | Accuracy 0.512
# k: 88 | Accuracy 0.515
# k: 89 | Accuracy 0.517
# k: 90 | Accuracy 0.517
# k: 91 | Accuracy 0.515
# k: 92 | Accuracy 0.514
# k: 93 | Accuracy 0.512
# k: 94 | Accuracy 0.510
# k: 95 | Accuracy 0.510
# k: 96 | Accuracy 0.503
# k: 97 | Accuracy 0.505
# k: 98 | Accuracy 0.505
# k: 99 | Accuracy 0.497
#
# Best k:  7 | Accuracy 0.570
